# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = ['Form Recognizer', 'Cloud Build', 'Cloud Run', 'Cloud Storage (images + containers)']
sizes = [300, 12.96, 0.3, 0.468 + 0.27]
explode = (0, 0, 0, 0)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = ['Form Recognizer', 'Other services']
sizes = [300, 12.96 + 0.3 + 0.468]

colors = ['#310783', '#078331']
explode = (0.05,0.05)
 
_, _, autotexts = plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85, explode = explode)

autotexts[1].set_color('white')
    
# draw circle
centre_circle = plt.Circle((0,0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

sizes = [300, 12.96 + 0.3 + 0.27 + 0.468]
total = sum(sizes)
print(total)

labels = [
    f'{sizes[0]/total*100:.1f}% Form Recognizer', 
    f'{sizes[1]/total*100:.1f}% Other services'
]

wedges, texts = ax.pie(sizes, wedgeprops=dict(width=0.5), startangle=-40, colors=colors)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(labels[i], size=10, xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

#ax.set_title("Operational costs")

plt.savefig("operational_costs.pdf", bbox_inches = 'tight')
# Out:
# 313.998
